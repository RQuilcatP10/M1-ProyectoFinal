# %% [markdown]
# <h1 align="center"><b>Visualización de Datos</b>
# <hr>

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f0b772b4-b555-4a5a-9fe4-9b4f4e4eec4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0b772b4-b555-4a5a-9fe4-9b4f4e4eec4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving putin_final_dataset.csv to putin_final_dataset.csv

# %%
data = pd.read_csv('putin_final_dataset.csv')
data.head()
# Out:
#                                           Tweet Text  ...  WebSite
# 0  potus ignores top intel, but we're supposed to...  ...        0
# 1  W.H.O won't announce Russian vaccine quick, it...  ...        1
# 2  Russian President Vladimir Putin has announced...  ...        0
# 3  Bullshit How many times has he said he trusts ...  ...        0
# 4  Half-baked' Russia vaccine may be 'little bett...  ...        0
#
# [5 rows x 8 columns]

# %%
spam_words = ' '.join(list(data[data['Label'] == 1]['Clean Tweet']))
spam_wc = WordCloud(width = 512,height = 512).generate(spam_words)
plt.figure(figsize = (6,6), facecolor = 'k')
plt.imshow(spam_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %%
ham_words = ' '.join(list(data[data['Label'] == 0]['Clean Tweet']))
ham_wc = WordCloud(width = 512,height = 512).generate(ham_words)
plt.figure(figsize = (6, 6), facecolor = 'k')
plt.imshow(ham_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %%
#length
plt.figure(figsize=(15,6))
bins = np.linspace(0,200,num=40)
plt.hist(data[data['Label']==1]['Lenght'],bins,alpha=0.5,label='Positivas')
plt.hist(data[data['Label']==0]['Lenght'],bins,alpha =0.5,label ='Negativas')
plt.legend(loc ='upper left')
plt.show()
