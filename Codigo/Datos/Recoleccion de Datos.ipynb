# %% [markdown]
# <h1 align="center"><b>Recolección de datos</b>
# <hr>

# %% [markdown]
# 1. Usando tweepy: creamos una cuenta en DEVELOPER TWITTER y nos dará una API por cada proyecto creado en dicha plataforma

# %%
import tweepy
import csv
import pandas as pd

# %% [markdown]
# 2. La API de Twitter funciona a través de keys, una para el usuario, una clave secreta para este mismo, y 2 tokens de acceso a la API

# %%
consumer_key = 'NbLFWy9cW9lmhO6MSvO3n5dFP'
consumer_secret = 'eqnpSm1vkR0WcswhNTAHDB9wkGW7ElMbNeeDdfxW9dM4DVqmWB'
access_token = '423736068-SHbbpgFt82Qjar2mM9lgvtaI8tELzQvrGsZL6eGQ'
access_token_secret = '1CsHva4QxTJFb9tHKbAk3nci6TQOuDHlM4lEZjxiU1fRD'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

csvFile = open('dataset.csv', 'a')
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search, q="Putin", count=100, lang="es", since="2020-08-08").items():
  print(tweet.created_at, tweet.text)
  csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# Streaming output truncated to the last 5000 lines.
# #covid_19 #vaccinecovid #Putin #China #Trump #Egos #bonilcartoons https://t.co/V1wBH…
# 2020-08-13 15:18:07 RT @maibortpetit: Un informe del gobierno ruso advierte que la vacuna anunciada por Vladimir Putin no es segura -  https://t.co/pUXKPWEUwD
# 2020-08-13 15:18:06 RT @romero_294f: Hay 2 hombres que tienen locas a las venezolanas, mi capitán @dcabellor y Vladimir Putin. Que queda para nosotros 😭😭
# 2020-08-13 15:18:06 Por las dudas, me pondré la vacuna de Oxford en el brazo derecho y la de Putin en el izquierdo profe @cfdeangelis,… https://t.co/loPF4bwfRM
# 2020-08-13 15:18:06 RT @HaffnerSoy: Putin luego de anunciar que Rusia ha registrado la vacuna contra el Coronavirus. https://t.co/DhBtPwbwW5
# 2020-08-13 15:18:05 RT @nachomdeo: Al final la solución no la trajo la reina de Tolosa desde la isla de Cuba, sino una empresa privada desde la isla de la rein…
# ...

# %%
import sys
replies=[] 
non_bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)  

for full_tweets in tweepy.Cursor(api.user_timeline,screen_name='jmartineze_',timeout=999999).items(10):
  for tweet in tweepy.Cursor(api.search,q='to:jmartineze_', since_id=1288599865338089479, result_type='recent',timeout=999999).items(1000):
    if hasattr(tweet, 'in_reply_to_status_id_str'):
      if (tweet.in_reply_to_status_id_str==full_tweets.id_str):
        replies.append(tweet.text)
  print("Tweet :",full_tweets.text.translate(non_bmp_map))
  for elements in replies:
       print("Replies :",elements)
  replies.clear()
# Out:
# Tweet : @94shossler @siriusdamelio @luvrhener ESTO NO ES UN CHAT VÁYANSE AL DM
# Replies : @jmartineze_ @94shossler @siriusdamelio @luvrhener vayan al dm putas 🙄🙄🙄
# Replies : @jmartineze_ @94shossler @siriusdamelio @luvrhener JSKSJSISJSIS
# Replies : @jmartineze_ @siriusdamelio @luvrhener PERO JOSI
# Replies : @jmartineze_ @94shossler @siriusdamelio JAJAJDSS SAME JOSI
# Replies : @jmartineze_ @94shossler @luvrhener JAJGJQJFJQJFJJFQJW trátanos bien
# Tweet : @siriusdamelio @luvrhener ALTA FANCAM HERMANA
# Replies : @jmartineze_ @siriusdamelio @luvrhener no te copies de putas
# Replies : @jmartineze_ @siriusdamelio josi no ves q sandrita y yo estamos estableciendo amistad, voy a llamar a… https://t.co/ndth6w509l
# Replies : @jmartineze_ @siriusdamelio @luvrhener se copiaba?
# Replies : @jmartineze_ @luvrhener q me copias quieres pelear
# Tweet : @virgovanisalame lo borre porque me comenzaron a decir de que 360 no se dice porque se queda en el mismo lugar
# ...
